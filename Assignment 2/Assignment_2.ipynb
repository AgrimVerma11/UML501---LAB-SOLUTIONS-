# %% [markdown]
# # Assignment 2 - ML
#
# Name - Agrim Verma    || Subgroup - 3C25 || Roll No. - 102303350

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv('AWCustomers.csv')
df
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            18361 non-null  int64
#  1   Title                 101 non-null    object
#  2   FirstName             18361 non-null  object
#  3   MiddleName            10572 non-null  object
#  4   LastName              18361 non-null  object
#  5   Suffix                3 non-null      object
#  6   AddressLine1          18361 non-null  object
#  7   AddressLine2          311 non-null    object
#  8   City                  18361 non-null  object
#  9   StateProvinceName     18361 non-null  object
#  10  CountryRegionName     18361 non-null  object
#  11  PostalCode            18361 non-null  object
#  12  PhoneNumber           18361 non-null  object
#  13  BirthDate             18361 non-null  object
#  14  Education             18361 non-null  object
# ...

# %% [markdown]
# # Solution to Part 1

# %% [markdown]
# On deep analysis of the given dataset, i have come to a conclusion that the following attributes/features are significant to predict future bike buyers -
#
# - City
# - Education
# - Occupation
# - Gender
# - Birthdate
# - Maritial status
# - Yearly Income

# %% [markdown]
# ## Creating a New Dataframe comprising of my selected features

# %%
newdf = pd.DataFrame(df,columns = ['City', 'Education', 'Occupation', 'Gender', 'Birthdate', 'MaritalStatus', 'YearlyIncome'])
newdf
# Out:
#                  City        Education      Occupation Gender  Birthdate  \
# 0          Wollongong        Bachelors        Clerical      M        NaN
# 1             Shawnee  Partial College        Clerical      M        NaN
# 2         West Covina        Bachelors        Clerical      F        NaN
# 3           Liverpool  Partial College  Skilled Manual      M        NaN
# 4               Werne  Partial College  Skilled Manual      M        NaN
# ...               ...              ...             ...    ...        ...
# 18356        Coronado  Graduate Degree  Skilled Manual      F        NaN
# 18357  Port Macquarie        Bachelors  Skilled Manual      F        NaN
# 18358       Beaverton  Partial College  Skilled Manual      F        NaN
# 18359       Vancouver      High School        Clerical      F        NaN
# 18360       Grossmont  Graduate Degree    Professional      F        NaN
#
#       MaritalStatus  YearlyIncome
# 0                 M         81916
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   City           18361 non-null  object
#  1   Education      18361 non-null  object
#  2   Occupation     18361 non-null  object
#  3   Gender         18361 non-null  object
#  4   Birthdate      0 non-null      float64
#  5   MaritalStatus  18361 non-null  object
#  6   YearlyIncome   18361 non-null  int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1004.2+ KB

# %% [markdown]
# ## Determining a data value type ( Discrete, Nominal, Ordinal, Interval , Ratio )

# %% [markdown]
# *   Discrete Data Column - City, Education, Occupation , Gender, MaritialStatus
# *   Continuos Data Column - Yearly Income, Birthdate
# *   Ordinal - Education
# *   Nominal - City , Occupation , Gender , MaritialStatus
# *   Ratio - Yearly Income , Birthdate
#
#
#
# ---
#
#
# Now when we have to do data preprocessing, i will follow this approach -
#
# **Nominal -** One Hot Encoding
#
# **Ordinal -** Mapping with integers (like 1,2,3....)
#
# **Continuos / Ratio -** Normalize or Standardize

# %% [markdown]
# ---

# %% [markdown]
# # Part 2 - Data Preprocessing and Transformation

# %%
newdf
# Out:
#                  City        Education      Occupation Gender  Birthdate  \
# 0          Wollongong        Bachelors        Clerical      M        NaN
# 1             Shawnee  Partial College        Clerical      M        NaN
# 2         West Covina        Bachelors        Clerical      F        NaN
# 3           Liverpool  Partial College  Skilled Manual      M        NaN
# 4               Werne  Partial College  Skilled Manual      M        NaN
# ...               ...              ...             ...    ...        ...
# 18356        Coronado  Graduate Degree  Skilled Manual      F        NaN
# 18357  Port Macquarie        Bachelors  Skilled Manual      F        NaN
# 18358       Beaverton  Partial College  Skilled Manual      F        NaN
# 18359       Vancouver      High School        Clerical      F        NaN
# 18360       Grossmont  Graduate Degree    Professional      F        NaN
#
#       MaritalStatus  YearlyIncome
# 0                 M         81916
# ...

# %% [markdown]
# ## Handling Null Values

# %%
newdf.isnull().sum()
# Out:
# City                 0
# Education            0
# Occupation           0
# Gender               0
# Birthdate        18361
# MaritalStatus        0
# YearlyIncome         0
# dtype: int64

# %% [markdown]
#  From the above data, i can see there is only one column having NULL values so my best option is to **Drop this column**

# %%
newdf.drop(labels=['Birthdate'],axis=1,inplace=True)

# %%
newdf
# Out:
#                  City        Education      Occupation Gender MaritalStatus  \
# 0          Wollongong        Bachelors        Clerical      M             M
# 1             Shawnee  Partial College        Clerical      M             M
# 2         West Covina        Bachelors        Clerical      F             S
# 3           Liverpool  Partial College  Skilled Manual      M             M
# 4               Werne  Partial College  Skilled Manual      M             S
# ...               ...              ...             ...    ...           ...
# 18356        Coronado  Graduate Degree  Skilled Manual      F             M
# 18357  Port Macquarie        Bachelors  Skilled Manual      F             S
# 18358       Beaverton  Partial College  Skilled Manual      F             S
# 18359       Vancouver      High School        Clerical      F             S
# 18360       Grossmont  Graduate Degree    Professional      F             M
#
#        YearlyIncome
# 0             81916
# ...

# %%
newdf.isnull().sum()
# Out:
# City             0
# Education        0
# Occupation       0
# Gender           0
# MaritalStatus    0
# YearlyIncome     0
# dtype: int64

# %% [markdown]
# Now i can see that my dataframe is free from any null values

# %% [markdown]
# ## Normalization

# %%
min_income = newdf['YearlyIncome'].min()
max_income = newdf['YearlyIncome'].max()
mean_income = newdf['YearlyIncome'].mean()

# %%
print("Min Yearly Income - ",min_income)
print("Max Yearly Income - ",max_income)
print("Mean Yearly Income - ",mean_income)
print("Income Difference - ", max_income - min_income)
# Out:
# Min Yearly Income -  25435
# Max Yearly Income -  139115
# Mean Yearly Income -  72754.77964163171
# Income Difference -  113680

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
scaler = MinMaxScaler()
newdf['YearlyIncome'] = scaler.fit_transform(newdf[['YearlyIncome']])

# %%
newdf
# Out:
#                  City        Education      Occupation Gender MaritalStatus  \
# 0          Wollongong        Bachelors        Clerical      M             M
# 1             Shawnee  Partial College        Clerical      M             M
# 2         West Covina        Bachelors        Clerical      F             S
# 3           Liverpool  Partial College  Skilled Manual      M             M
# 4               Werne  Partial College  Skilled Manual      M             S
# ...               ...              ...             ...    ...           ...
# 18356        Coronado  Graduate Degree  Skilled Manual      F             M
# 18357  Port Macquarie        Bachelors  Skilled Manual      F             S
# 18358       Beaverton  Partial College  Skilled Manual      F             S
# 18359       Vancouver      High School        Clerical      F             S
# 18360       Grossmont  Graduate Degree    Professional      F             M
#
#        YearlyIncome
# 0          0.496842
# ...

# %%
print("After Normalization")
print("Min = ", newdf['YearlyIncome'].min())
print("Max = ", newdf['YearlyIncome'].max())
# Out:
# After Normalization
# Min =  0.0
# Max =  0.9999999999999999

# %% [markdown]
# ## Binarization
#
# using one-hot encoding on the Gender column to convert the categorical data into numerical data

# %%
newdf = pd.get_dummies(newdf, columns=["City", "Occupation", "MaritalStatus"], drop_first=True)

# %%
newdf
# Out:
#              Education Gender  YearlyIncome  City_Baltimore  City_Barstow  \
# 0            Bachelors      M      0.496842           False         False
# 1      Partial College      M      0.489453           False         False
# 2            Bachelors      F      0.536172           False         False
# 3      Partial College      M      0.317083           False         False
# 4      Partial College      M      0.231958           False         False
# ...                ...    ...           ...             ...           ...
# 18356  Graduate Degree      F      0.242065           False         False
# 18357        Bachelors      F      0.312781           False         False
# 18358  Partial College      F      0.232442           False         False
# 18359      High School      F      0.543121           False         False
# 18360  Graduate Degree      F      0.980128           False         False
#
#        City_Basingstoke Hants  City_Baytown  City_Beaverton  \
# ...

# %% [markdown]
# # Part 3

# %% [markdown]
# Ma'am I am in need of your kind guidance in this part, despite my efforts to understand the approach, i am not able to figure it out.
#
# Best Regards

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import jaccard_score
import pandas as pd

scaler = StandardScaler()
newdf[["YearlyIncome", "Age", "CommuteDistance"]] = scaler.fit_transform(newdf[["YearlyIncome", "Age", "CommuteDistance"]])

newdf = pd.get_dummies(newdf, columns=["MaritalStatus", "Occupation", "City"], drop_first=True)

obj1 = newdf.iloc[0].values
obj2 = newdf.iloc[1].values

smc = (obj1 == obj2).sum() / len(obj1)

jaccard = jaccard_score(obj1, obj2, average="binary")

cos_sim = cosine_similarity([obj1], [obj2])[0][0]

corr = newdf["CommuteDistance"].corr(newdf["YearlyIncome"], method="pearson")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1186409201.py in <cell line: 0>()
#       5
#       6 scaler = StandardScaler()
# ----> 7 newdf[["YearlyIncome", "Age", "CommuteDistance"]] = scaler.fit_transform(newdf[["YearlyIncome", "Age", "CommuteDistance"]])
#       8
#       9 newdf = pd.get_dummies(newdf, columns=["MaritalStatus", "Occupation", "City"], drop_first=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...
